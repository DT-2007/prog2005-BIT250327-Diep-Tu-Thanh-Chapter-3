# %%
#Bài 1
mon_hoc = ["Toán", "Lý", "Hóa", "Tin"]

print("Số môn học:", len(mon_hoc))

for mon in mon_hoc:
    print(mon)

# %%
#Bài 2
ban = ["An", "Bình", "Chi"]

ban.append("Dũng")
print("Sau khi thêm:", ban)

ban.pop(1)
print("Sau khi xóa:", ban)

# %%
#Bài 3
mau = ["Red", "Blue", "Green", "Yellow", "Black"]

try:
    mau.remove("Green")
except:
    print("Không có màu Green")

print("Danh sách:", mau)

# %%
#Bài 4
nums = [5, 2, 8, 1, 5, 3]

nums.sort()
print("Tăng dần:", nums)

nums.reverse()
print("Đảo ngược:", nums)

print("Số lần xuất hiện của 5:", nums.count(5))

# %%
#Bài 5
arr = list(map(float, input("Nhập các số: ").split()))

for i in range(1, len(arr)):
    key = arr[i]
    j = i - 1

    while j >= 0 and arr[j] < key:
        arr[j + 1] = arr[j]
        j -= 1

    arr[j + 1] = key

print("Danh sách sau khi sắp xếp:", arr)

# %%
#Bài 6
arr = list(map(int, input("Nhập các số: ").split()))
count = 0

for i in range(len(arr)):
    for j in range(len(arr) - 1 - i):
        if arr[j] > arr[j + 1]:
            arr[j], arr[j + 1] = arr[j + 1], arr[j]
            count += 1

print("Danh sách sau sắp xếp:", arr)
print("Số lần hoán đổi:", count)

# %%
#Bài 7
arr = list(map(int, input("Nhập danh sách số: ").split()))
x = int(input("Nhập số cần tìm: "))

index = -1

for i in range(len(arr)):
    if arr[i] == x:
        index = i
        break

if index != -1:
    print("Vị trí:", index)
else:
    print("Không tìm thấy")

# %%
#Bài 8
arr = list(map(int, input("Nhập danh sách số: ").split()))

found = None

for num in arr:
    if num > 10:
        found = num
        break

if found:
    print("Số đầu tiên > 10:", found)
else:
    print("Không có số > 10")

# %%
#Bài 9
arr = list(map(int, input("Nhập danh sách số: ").split()))

print("Các số lẻ:")
for num in arr:
    if num % 2 != 0:
        print(num)

# %%
#Bài 10
arr = list(map(int, input("Nhập danh sách số: ").split()))

tong = 0

for num in arr:
    if num % 2 == 0:
        print(num)
        tong += num

print("Tổng số chẵn:", tong)

# %%
#Bài 11
arr = list(map(int, input("Nhập danh sách số: ").split()))

print("Max:", max(arr))
print("Min:", min(arr))

# %%
#Bài 12
m = int(input("Nhập số hàng: "))
n = int(input("Nhập số cột: "))

A = []
B = []
C = []

print("Nhập ma trận A")
for i in range(m):
    row = list(map(int, input().split()))
    A.append(row)

print("Nhập ma trận B")
for i in range(m):
    row = list(map(int, input().split()))
    B.append(row)

for i in range(m):
    row = []
    for j in range(n):
        row.append(A[i][j] + B[i][j])
    C.append(row)

print("Ma trận tổng:")
for row in C:
    print(row)

# %%
#Bài 13
s = input("Nhập chuỗi: ")

if s == s[::-1]:
    print("Chuỗi đối xứng")
else:
    print("Không phải đối xứng")

# %%
#Bài 14
def count_vowels(s):
    vowels = "aeiouAEIOU"
    count = 0

    for c in s:
        if c in vowels:
            count += 1

    return count

s = input("Nhập chuỗi: ")
print("Số nguyên âm:", count_vowels(s))

# %%
#Bài 15 ( Dùng Slicing )
s = input("Nhập chuỗi: ")
print("Chuỗi đảo:", s[::-1])
# Out:
# Chuỗi đảo: 21

# %%
#Bài 15 ( Không Dùng Slicing )
s = input("Nhập chuỗi: ")

rev = ""
for c in s:
    rev = c + rev

print("Chuỗi đảo:", rev)
# Out:
# Chuỗi đảo: 321
